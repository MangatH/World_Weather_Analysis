# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 778

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | phan thiet
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | songjianghe
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | valera
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | kushmurun
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | sitangkai
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | joshimath
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | sao joao da barra
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | balikpapan
# Processing Record 28 of Set 1 | medicine hat
# Processing Record 29 of Set 1 | markova
# Processing Record 30 of Set 1 | hun
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | mega
# Processing Record 33 of Set 1 | arman
# Processing Record 34 of Set 1 | coihaique
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | college
# Processing Record 39 of Set 1 | arteni
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | abu samrah
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 1 | alekseyevskoye
# Processing Record 48 of Set 1 | brae
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | hambantota
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | portland
# Processing Record 7 of Set 2 | meulaboh
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | nouadhibou
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | stawell
# Processing Record 17 of Set 2 | sungairaya
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | russas
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | fare
# Processing Record 22 of Set 2 | coxim
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | parati
# Processing Record 25 of Set 2 | halifax
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | adrar
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 2 | aykhal
# Processing Record 36 of Set 2 | sorland
# Processing Record 37 of Set 2 | pocao de pedras
# Processing Record 38 of Set 2 | yar-sale
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 2 | leningradskiy
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | semporna
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | riviere-au-renard
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | humaita
# Processing Record 48 of Set 2 | olutanga
# Processing Record 49 of Set 2 | blyth
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 2 of Set 3 | fukue
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | viedma
# Processing Record 6 of Set 3 | dunda
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 3 | manoel urbano
# Processing Record 10 of Set 3 | punta arenas
# Processing Record 11 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 12 of Set 3 | rawson
# Processing Record 13 of Set 3 | coos bay
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | asosa
# Processing Record 16 of Set 3 | erzin
# Processing Record 17 of Set 3 | pincher creek
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | hobyo
# Processing Record 23 of Set 3 | fuyang
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | saint-augustin
# Processing Record 26 of Set 3 | gogrial
# Processing Record 27 of Set 3 | uzhur
# Processing Record 28 of Set 3 | hemsedal
# Processing Record 29 of Set 3 | la asuncion
# Processing Record 30 of Set 3 | vaitape
# Processing Record 31 of Set 3 | amarante do maranhao
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | yauya
# Processing Record 35 of Set 3 | glubokiy
# Processing Record 36 of Set 3 | nome
# Processing Record 37 of Set 3 | xapuri
# Processing Record 38 of Set 3 | puri
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | turbat
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | hirara
# Processing Record 43 of Set 3 | isangel
# Processing Record 44 of Set 3 | linhai
# Processing Record 45 of Set 3 | opuwo
# Processing Record 46 of Set 3 | palauig
# Processing Record 47 of Set 3 | bathurst
# Processing Record 48 of Set 3 | dali
# Processing Record 49 of Set 3 | doha
# Processing Record 50 of Set 3 | sinegorye
# Processing Record 1 of Set 4 | keti bandar
# Processing Record 2 of Set 4 | la ronge
# Processing Record 3 of Set 4 | el escorial
# Processing Record 4 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 4 | jamestown
# Processing Record 6 of Set 4 | kizukuri
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | mount isa
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | jumla
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | nobeoka
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | hermanus
# Processing Record 20 of Set 4 | moose factory
# Processing Record 21 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | buala
# Processing Record 23 of Set 4 | serik
# Processing Record 24 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 4 | labuan
# Processing Record 26 of Set 4 | nemuro
# Processing Record 27 of Set 4 | wasilla
# Processing Record 28 of Set 4 | hualmay
# Processing Record 29 of Set 4 | atasu
# Processing Record 30 of Set 4 | huaiyin
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | kahului
# Processing Record 35 of Set 4 | kroya
# Processing Record 36 of Set 4 | lorengau
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 4 | cedral
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | vila franca do campo
# Processing Record 42 of Set 4 | semirom
# Processing Record 43 of Set 4 | abashiri
# Processing Record 44 of Set 4 | wilmington island
# Processing Record 45 of Set 4 | red bluff
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | terrasini
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | kirakira
# Processing Record 50 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 5 | bubaque
# Processing Record 2 of Set 5 | batemans bay
# Processing Record 3 of Set 5 | villa florida
# Processing Record 4 of Set 5 | muskegon
# Processing Record 5 of Set 5 | nizwa
# Processing Record 6 of Set 5 | soderhamn
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | bowen
# Processing Record 9 of Set 5 | steinbach
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | cabo san lucas
# Processing Record 12 of Set 5 | cap-aux-meules
# Processing Record 13 of Set 5 | darhan
# Processing Record 14 of Set 5 | vardo
# Processing Record 15 of Set 5 | aswan
# Processing Record 16 of Set 5 | oranjemund
# Processing Record 17 of Set 5 | nikolskoye
# Processing Record 18 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 19 of Set 5 | boa vista
# Processing Record 20 of Set 5 | manzhouli
# Processing Record 21 of Set 5 | bethanien
# Processing Record 22 of Set 5 | pochutla
# Processing Record 23 of Set 5 | mahajanga
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | broome
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | cuamba
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 5 | espanola
# Processing Record 31 of Set 5 | yichun
# Processing Record 32 of Set 5 | sloboda
# Processing Record 33 of Set 5 | labuhan
# Processing Record 34 of Set 5 | coahuayana
# Processing Record 35 of Set 5 | japura
# Processing Record 36 of Set 5 | muscat
# Processing Record 37 of Set 5 | langres
# Processing Record 38 of Set 5 | verkhoyansk
# Processing Record 39 of Set 5 | jinxiang
# Processing Record 40 of Set 5 | taoudenni
# Processing Record 41 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | novoraychikhinsk
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | semey
# Processing Record 46 of Set 5 | zalantun
# Processing Record 47 of Set 5 | dronninglund
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | ajaigarh
# Processing Record 50 of Set 5 | karratha
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | ponferrada
# Processing Record 3 of Set 6 | kawambwa
# Processing Record 4 of Set 6 | alice town
# Processing Record 5 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 6 of Set 6 | santa ana
# Processing Record 7 of Set 6 | acara
# Processing Record 8 of Set 6 | altus
# Processing Record 9 of Set 6 | jieshi
# Processing Record 10 of Set 6 | zyryanka
# Processing Record 11 of Set 6 | havre-saint-pierre
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | rundu
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | flin flon
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | manokwari
# Processing Record 20 of Set 6 | lahaina
# Processing Record 21 of Set 6 | mojo
# Processing Record 22 of Set 6 | traverse city
# Processing Record 23 of Set 6 | mandera
# Processing Record 24 of Set 6 | mogadishu
# Processing Record 25 of Set 6 | harer
# Processing Record 26 of Set 6 | tezu
# Processing Record 27 of Set 6 | maralal
# Processing Record 28 of Set 6 | christiana
# Processing Record 29 of Set 6 | seoul
# Processing Record 30 of Set 6 | bereda
# Processing Record 31 of Set 6 | usinsk
# Processing Record 32 of Set 6 | caninde
# Processing Record 33 of Set 6 | nha trang
# Processing Record 34 of Set 6 | tonota
# Processing Record 35 of Set 6 | caravelas
# Processing Record 36 of Set 6 | camocim
# Processing Record 37 of Set 6 | wrexham
# Processing Record 38 of Set 6 | dagana
# Processing Record 39 of Set 6 | wajima
# Processing Record 40 of Set 6 | iquique
# Processing Record 41 of Set 6 | tual
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | barroquinha
# Processing Record 44 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 45 of Set 6 | yima
# Processing Record 46 of Set 6 | charters towers
# Processing Record 47 of Set 6 | guicheng
# City not found. Skipping...
# Processing Record 48 of Set 6 | leshukonskoye
# Processing Record 49 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 50 of Set 6 | qaanaaq
# Processing Record 1 of Set 7 | ostrovnoy
# Processing Record 2 of Set 7 | urumqi
# Processing Record 3 of Set 7 | castro
# Processing Record 4 of Set 7 | dawei
# Processing Record 5 of Set 7 | trelew
# Processing Record 6 of Set 7 | poim
# Processing Record 7 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 7 | usolye
# Processing Record 9 of Set 7 | vila velha
# Processing Record 10 of Set 7 | lerwick
# Processing Record 11 of Set 7 | selfoss
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | thunder bay
# Processing Record 16 of Set 7 | shache
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | celestun
# Processing Record 19 of Set 7 | vrangel
# Processing Record 20 of Set 7 | faanui
# Processing Record 21 of Set 7 | witney
# Processing Record 22 of Set 7 | praia
# Processing Record 23 of Set 7 | norden
# Processing Record 24 of Set 7 | muncar
# Processing Record 25 of Set 7 | vung tau
# Processing Record 26 of Set 7 | nhulunbuy
# Processing Record 27 of Set 7 | tarakan
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | kloulklubed
# Processing Record 30 of Set 7 | tessalit
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | mizdah
# Processing Record 33 of Set 7 | wattegama
# Processing Record 34 of Set 7 | bandar penggaram
# City not found. Skipping...
# Processing Record 35 of Set 7 | kampong thum
# Processing Record 36 of Set 7 | acopiara
# Processing Record 37 of Set 7 | maceio
# Processing Record 38 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 7 | marzuq
# Processing Record 40 of Set 7 | makakilo city
# Processing Record 41 of Set 7 | georgetown
# Processing Record 42 of Set 7 | volot
# Processing Record 43 of Set 7 | necochea
# Processing Record 44 of Set 7 | akyab
# Processing Record 45 of Set 7 | mayo
# Processing Record 46 of Set 7 | broken hill
# Processing Record 47 of Set 7 | clyde river
# Processing Record 48 of Set 7 | palafrugell
# Processing Record 49 of Set 7 | lafia
# Processing Record 50 of Set 7 | baykit
# Processing Record 1 of Set 8 | praya
# Processing Record 2 of Set 8 | cortland
# Processing Record 3 of Set 8 | sangueya
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | alugan
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | rivers
# Processing Record 8 of Set 8 | challapata
# Processing Record 9 of Set 8 | roshchino
# Processing Record 10 of Set 8 | kedrovyy
# Processing Record 11 of Set 8 | biak
# Processing Record 12 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 8 | jijiga
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | tambopata
# Processing Record 16 of Set 8 | senneterre
# Processing Record 17 of Set 8 | russell
# Processing Record 18 of Set 8 | vanavara
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | mikuni
# Processing Record 21 of Set 8 | shimoda
# Processing Record 22 of Set 8 | auki
# Processing Record 23 of Set 8 | bakchar
# Processing Record 24 of Set 8 | kamien pomorski
# Processing Record 25 of Set 8 | camana
# Processing Record 26 of Set 8 | ambilobe
# Processing Record 27 of Set 8 | bossangoa
# Processing Record 28 of Set 8 | grand gaube
# Processing Record 29 of Set 8 | okhotsk
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | port keats
# Processing Record 32 of Set 8 | sompeta
# Processing Record 33 of Set 8 | conceicao da barra
# Processing Record 34 of Set 8 | manono
# Processing Record 35 of Set 8 | panormos
# Processing Record 36 of Set 8 | sironj
# Processing Record 37 of Set 8 | namtsy
# Processing Record 38 of Set 8 | jardim
# Processing Record 39 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | wiang sa
# Processing Record 41 of Set 8 | martapura
# Processing Record 42 of Set 8 | ondjiva
# Processing Record 43 of Set 8 | kerouane
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | galle
# Processing Record 46 of Set 8 | grand baie
# Processing Record 47 of Set 8 | san quintin
# Processing Record 48 of Set 8 | thyboron
# Processing Record 49 of Set 8 | uthal
# Processing Record 50 of Set 8 | te anau
# Processing Record 1 of Set 9 | lashio
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | tabas
# Processing Record 4 of Set 9 | viksoyri
# City not found. Skipping...
# Processing Record 5 of Set 9 | juneau
# Processing Record 6 of Set 9 | ginda
# Processing Record 7 of Set 9 | sao jose da coroa grande
# Processing Record 8 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 9 | dzhebariki-khaya
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | half moon bay
# Processing Record 12 of Set 9 | naze
# Processing Record 13 of Set 9 | erenhot
# Processing Record 14 of Set 9 | chardara
# Processing Record 15 of Set 9 | poum
# Processing Record 16 of Set 9 | bonavista
# Processing Record 17 of Set 9 | kieta
# Processing Record 18 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 9 | denpasar
# Processing Record 20 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 9 | adeje
# Processing Record 22 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 9 | mogocha
# Processing Record 24 of Set 9 | huntsville
# Processing Record 25 of Set 9 | oktyabrskiy
# Processing Record 26 of Set 9 | los llanos de aridane
# Processing Record 27 of Set 9 | hovd
# Processing Record 28 of Set 9 | saryozek
# Processing Record 29 of Set 9 | gombong
# Processing Record 30 of Set 9 | mahibadhoo
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | suntar
# Processing Record 34 of Set 9 | katherine
# Processing Record 35 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | burgersdorp
# Processing Record 38 of Set 9 | khatanga
# Processing Record 39 of Set 9 | kachiry
# Processing Record 40 of Set 9 | krasnoselkup
# Processing Record 41 of Set 9 | saskylakh
# Processing Record 42 of Set 9 | nago
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | saint-francois
# Processing Record 45 of Set 9 | trincomalee
# Processing Record 46 of Set 9 | burica
# City not found. Skipping...
# Processing Record 47 of Set 9 | acajutla
# Processing Record 48 of Set 9 | tambo grande
# Processing Record 49 of Set 9 | ayan
# Processing Record 50 of Set 9 | omsukchan
# Processing Record 1 of Set 10 | vinkovci
# Processing Record 2 of Set 10 | mwinilunga
# Processing Record 3 of Set 10 | asau
# Processing Record 4 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 5 of Set 10 | gisborne
# Processing Record 6 of Set 10 | marawi
# Processing Record 7 of Set 10 | asmara
# Processing Record 8 of Set 10 | thinadhoo
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | yining
# Processing Record 11 of Set 10 | coquimbo
# Processing Record 12 of Set 10 | rehoboth
# Processing Record 13 of Set 10 | french harbor
# Processing Record 14 of Set 10 | berberati
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | katsuura
# Processing Record 17 of Set 10 | san carlos de bariloche
# Processing Record 18 of Set 10 | zarinsk
# Processing Record 19 of Set 10 | iqaluit
# Processing Record 20 of Set 10 | airai
# Processing Record 21 of Set 10 | punta de bombon
# Processing Record 22 of Set 10 | muros
# Processing Record 23 of Set 10 | victoria point
# Processing Record 24 of Set 10 | roanoke rapids
# Processing Record 25 of Set 10 | camalu
# Processing Record 26 of Set 10 | patitirion
# Processing Record 27 of Set 10 | vostok
# Processing Record 28 of Set 10 | dingle
# Processing Record 29 of Set 10 | pouembout
# Processing Record 30 of Set 10 | sioux lookout
# Processing Record 31 of Set 10 | pisco
# Processing Record 32 of Set 10 | loyola
# Processing Record 33 of Set 10 | albanel
# Processing Record 34 of Set 10 | pinega
# Processing Record 35 of Set 10 | miyako
# Processing Record 36 of Set 10 | san luis
# Processing Record 37 of Set 10 | alexandria
# Processing Record 38 of Set 10 | trzebnica
# Processing Record 39 of Set 10 | daru
# Processing Record 40 of Set 10 | katobu
# Processing Record 41 of Set 10 | mana
# Processing Record 42 of Set 10 | cap malheureux
# Processing Record 43 of Set 10 | abu kamal
# Processing Record 44 of Set 10 | komsomolskiy
# Processing Record 45 of Set 10 | qingyuan
# Processing Record 46 of Set 10 | murray
# Processing Record 47 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 10 | urazovka
# Processing Record 49 of Set 10 | wewak
# Processing Record 50 of Set 10 | makinsk
# Processing Record 1 of Set 11 | mildura
# Processing Record 2 of Set 11 | promyshlennovskiy
# Processing Record 3 of Set 11 | athabasca
# Processing Record 4 of Set 11 | roebourne
# Processing Record 5 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 11 | anloga
# Processing Record 7 of Set 11 | klaksvik
# Processing Record 8 of Set 11 | tottori
# Processing Record 9 of Set 11 | nanortalik
# Processing Record 10 of Set 11 | dubbo
# Processing Record 11 of Set 11 | wagar
# Processing Record 12 of Set 11 | lensk
# Processing Record 13 of Set 11 | puro
# Processing Record 14 of Set 11 | ndjole
# Processing Record 15 of Set 11 | rudbar
# Processing Record 16 of Set 11 | santa cruz de la palma
# Processing Record 17 of Set 11 | kitimat
# Processing Record 18 of Set 11 | atar
# Processing Record 19 of Set 11 | mount gambier
# Processing Record 20 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | pierre
# Processing Record 22 of Set 11 | aborlan
# Processing Record 23 of Set 11 | khuzdar
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | tilichiki
# Processing Record 26 of Set 11 | piacabucu
# Processing Record 27 of Set 11 | kongolo
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | narrabri
# Processing Record 30 of Set 11 | ahualulco
# Processing Record 31 of Set 11 | balkhash
# Processing Record 32 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 11 | phangnga
# Processing Record 34 of Set 11 | poninka
# Processing Record 35 of Set 11 | kuching
# Processing Record 36 of Set 11 | sawtell
# Processing Record 37 of Set 11 | dukat
# Processing Record 38 of Set 11 | kijang
# Processing Record 39 of Set 11 | morant bay
# Processing Record 40 of Set 11 | turayf
# Processing Record 41 of Set 11 | barcelos
# Processing Record 42 of Set 11 | redcliffe
# Processing Record 43 of Set 11 | jarvenpaa
# Processing Record 44 of Set 11 | hailey
# Processing Record 45 of Set 11 | ha tinh
# Processing Record 46 of Set 11 | roald
# Processing Record 47 of Set 11 | rio grande
# Processing Record 48 of Set 11 | petatlan
# Processing Record 49 of Set 11 | galesong
# Processing Record 50 of Set 11 | vila
# Processing Record 1 of Set 12 | male
# Processing Record 2 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 12 | floresta
# Processing Record 4 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | turukhansk
# Processing Record 6 of Set 12 | sangar
# Processing Record 7 of Set 12 | ornskoldsvik
# Processing Record 8 of Set 12 | bassano
# Processing Record 9 of Set 12 | cuajinicuilapa
# Processing Record 10 of Set 12 | harper
# Processing Record 11 of Set 12 | weligama
# Processing Record 12 of Set 12 | porto torres
# Processing Record 13 of Set 12 | juba
# Processing Record 14 of Set 12 | surt
# Processing Record 15 of Set 12 | rio gallegos
# Processing Record 16 of Set 12 | gazanjyk
# Processing Record 17 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 12 | keuruu
# Processing Record 19 of Set 12 | marathon
# Processing Record 20 of Set 12 | qasigiannguit
# Processing Record 21 of Set 12 | nisia floresta
# Processing Record 22 of Set 12 | ahmadpur east
# Processing Record 23 of Set 12 | shagonar
# Processing Record 24 of Set 12 | itigi
# Processing Record 25 of Set 12 | cockburn town
# Processing Record 26 of Set 12 | inhambane
# Processing Record 27 of Set 12 | novyy svit
# Processing Record 28 of Set 12 | husavik
# Processing Record 29 of Set 12 | livingston
# Processing Record 30 of Set 12 | sanmenxia
# Processing Record 31 of Set 12 | kodinar
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | ixtapa
# Processing Record 34 of Set 12 | chatra
# Processing Record 35 of Set 12 | tongren
# Processing Record 36 of Set 12 | voyvozh
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 12 | jerantut
# Processing Record 40 of Set 12 | mangai
# Processing Record 41 of Set 12 | moussoro
# Processing Record 42 of Set 12 | voh
# Processing Record 43 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 44 of Set 12 | alibag
# Processing Record 45 of Set 12 | wanaka
# Processing Record 46 of Set 12 | iwanai
# Processing Record 47 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 12 | port hedland
# Processing Record 49 of Set 12 | miandrivazo
# Processing Record 50 of Set 12 | dieppe bay
# City not found. Skipping...
# Processing Record 1 of Set 13 | svetlogorsk
# Processing Record 2 of Set 13 | buzmeyin
# Processing Record 3 of Set 13 | kannangad
# Processing Record 4 of Set 13 | carleton place
# Processing Record 5 of Set 13 | havre
# Processing Record 6 of Set 13 | road town
# Processing Record 7 of Set 13 | maniitsoq
# Processing Record 8 of Set 13 | mercedes
# Processing Record 9 of Set 13 | kruisfontein
# Processing Record 10 of Set 13 | shetpe
# Processing Record 11 of Set 13 | mionica
# Processing Record 12 of Set 13 | vao
# Processing Record 13 of Set 13 | christchurch
# Processing Record 14 of Set 13 | ketchikan
# Processing Record 15 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 13 | bandarbeyla
# Processing Record 17 of Set 13 | tarko-sale
# Processing Record 18 of Set 13 | kyotera
# Processing Record 19 of Set 13 | vestmannaeyjar
# Processing Record 20 of Set 13 | axim
# Processing Record 21 of Set 13 | trstenik
# Processing Record 22 of Set 13 | hernani
# Processing Record 23 of Set 13 | khandyga
# Processing Record 24 of Set 13 | magan
# Processing Record 25 of Set 13 | maine-soroa
# Processing Record 26 of Set 13 | panlaitan
# Processing Record 27 of Set 13 | sapa
# Processing Record 28 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 29 of Set 13 | canico
# Processing Record 30 of Set 13 | gushikawa
# Processing Record 31 of Set 13 | port augusta
# Processing Record 32 of Set 13 | veraval
# Processing Record 33 of Set 13 | fort-shevchenko
# Processing Record 34 of Set 13 | sao filipe
# Processing Record 35 of Set 13 | iracoubo
# Processing Record 36 of Set 13 | naples
# Processing Record 37 of Set 13 | metro
# Processing Record 38 of Set 13 | paita
# Processing Record 39 of Set 13 | qandala
# Processing Record 40 of Set 13 | rong kwang
# Processing Record 41 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 13 | smithers
# Processing Record 43 of Set 13 | camaqua
# Processing Record 44 of Set 13 | hinton
# Processing Record 45 of Set 13 | trairi
# Processing Record 46 of Set 13 | swan hill
# Processing Record 47 of Set 13 | soe
# Processing Record 48 of Set 13 | ndele
# Processing Record 49 of Set 13 | qaqortoq
# Processing Record 50 of Set 13 | liapades
# City not found. Skipping...
# Processing Record 1 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 14 | tomatlan
# Processing Record 3 of Set 14 | muroto
# Processing Record 4 of Set 14 | kefalos
# Processing Record 5 of Set 14 | fort nelson
# Processing Record 6 of Set 14 | mola di bari
# Processing Record 7 of Set 14 | clearlake
# Processing Record 8 of Set 14 | atambua
# Processing Record 9 of Set 14 | honavar
# Processing Record 10 of Set 14 | great yarmouth
# Processing Record 11 of Set 14 | matias romero
# Processing Record 12 of Set 14 | lewisville
# Processing Record 13 of Set 14 | porto novo
# Processing Record 14 of Set 14 | rupert
# Processing Record 15 of Set 14 | krasnogorsk
# Processing Record 16 of Set 14 | yaan
# Processing Record 17 of Set 14 | mabaruma
# Processing Record 18 of Set 14 | nurota
# Processing Record 19 of Set 14 | araouane
# Processing Record 20 of Set 14 | salinopolis
# Processing Record 21 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 14 | praia da vitoria
# Processing Record 23 of Set 14 | bagamoyo
# Processing Record 24 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 14 | the valley
# Processing Record 26 of Set 14 | chastoozerye
# City not found. Skipping...
# Processing Record 27 of Set 14 | aguimes
# Processing Record 28 of Set 14 | vaovai
# City not found. Skipping...
# Processing Record 29 of Set 14 | djibo
# Processing Record 30 of Set 14 | ossora
# Processing Record 31 of Set 14 | elko
# Processing Record 32 of Set 14 | batangafo
# Processing Record 33 of Set 14 | dong hoi
# Processing Record 34 of Set 14 | rockport
# Processing Record 35 of Set 14 | jacareacanga
# Processing Record 36 of Set 14 | beinamar
# Processing Record 37 of Set 14 | ronne
# Processing Record 38 of Set 14 | pinawa
# Processing Record 39 of Set 14 | takaka
# Processing Record 40 of Set 14 | novobelokatay
# Processing Record 41 of Set 14 | oistins
# Processing Record 42 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 14 | pingliang
# Processing Record 44 of Set 14 | troyes
# Processing Record 45 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 14 | codrington
# Processing Record 47 of Set 14 | lyubytino
# Processing Record 48 of Set 14 | caraz
# Processing Record 49 of Set 14 | alikalia
# Processing Record 50 of Set 14 | gondomar
# Processing Record 1 of Set 15 | buchanan
# Processing Record 2 of Set 15 | dauphin
# Processing Record 3 of Set 15 | tabuk
# Processing Record 4 of Set 15 | marsh harbour
# Processing Record 5 of Set 15 | lasa
# Processing Record 6 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 15 | faya
# Processing Record 8 of Set 15 | lata
# Processing Record 9 of Set 15 | ust-nera
# Processing Record 10 of Set 15 | atbasar
# Processing Record 11 of Set 15 | banjar
# Processing Record 12 of Set 15 | acapulco
# Processing Record 13 of Set 15 | alta floresta
# Processing Record 14 of Set 15 | hamilton
# Processing Record 15 of Set 15 | sampit
# Processing Record 16 of Set 15 | warmbad
# Processing Record 17 of Set 15 | acarau
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | udachnyy
# Processing Record 20 of Set 15 | kaeo
# Processing Record 21 of Set 15 | ambulu
# Processing Record 22 of Set 15 | kalisz
# Processing Record 23 of Set 15 | irbeyskoye
# Processing Record 24 of Set 15 | lesnoy
# Processing Record 25 of Set 15 | porkhov
# Processing Record 26 of Set 15 | tautira
# Processing Record 27 of Set 15 | tuy hoa
# Processing Record 28 of Set 15 | sitka
# Processing Record 29 of Set 15 | comodoro rivadavia
# Processing Record 30 of Set 15 | radeberg
# Processing Record 31 of Set 15 | taksimo
# Processing Record 32 of Set 15 | kill
# Processing Record 33 of Set 15 | chegem
# Processing Record 34 of Set 15 | palana
# Processing Record 35 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 15 | goderich
# Processing Record 37 of Set 15 | tadine
# Processing Record 38 of Set 15 | ahuimanu
# Processing Record 39 of Set 15 | sao gabriel da cachoeira
# Processing Record 40 of Set 15 | avera
# Processing Record 41 of Set 15 | emerald
# Processing Record 42 of Set 15 | telford
# Processing Record 43 of Set 15 | hagenow
# Processing Record 44 of Set 15 | kortkeros
# Processing Record 45 of Set 15 | westport
# Processing Record 46 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 15 | mizur
# Processing Record 48 of Set 15 | honiara
# Processing Record 49 of Set 15 | naryan-mar
# Processing Record 50 of Set 15 | qena
# Processing Record 1 of Set 16 | yiyang
# Processing Record 2 of Set 16 | ibirite
# Processing Record 3 of Set 16 | almaznyy
# Processing Record 4 of Set 16 | matara
# Processing Record 5 of Set 16 | ciras
# City not found. Skipping...
# Processing Record 6 of Set 16 | henties bay
# Processing Record 7 of Set 16 | pullman
# Processing Record 8 of Set 16 | kampene
# Processing Record 9 of Set 16 | sechura
# Processing Record 10 of Set 16 | beloha
# Processing Record 11 of Set 16 | uarini
# Processing Record 12 of Set 16 | washington
# Processing Record 13 of Set 16 | sur
# Processing Record 14 of Set 16 | srednekolymsk
# Processing Record 15 of Set 16 | imeni stepana razina
# Processing Record 16 of Set 16 | roma
# Processing Record 17 of Set 16 | ivybridge
# Processing Record 18 of Set 16 | roseburg
# Processing Record 19 of Set 16 | zhitikara
# City not found. Skipping...
# Processing Record 20 of Set 16 | san policarpo
# Processing Record 21 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 16 | esso
# Processing Record 23 of Set 16 | ishigaki
# Processing Record 24 of Set 16 | miedzychod
# Processing Record 25 of Set 16 | bardiyah
# Processing Record 26 of Set 16 | eyl
# Processing Record 27 of Set 16 | kupang
# Processing Record 28 of Set 16 | methven
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Thompson  55.7435  -97.8558     51.96        82           0
# 1       Phan Thiet  10.9333  108.1000     83.68        76          82
# 2      East London -33.0153   27.9116     67.14        72           0
# 3           Atuona  -9.8000 -139.0333     76.69        74           9
# 4  Bambous Virieux -20.3428   57.7575     77.25        65          75
# 5        Mahebourg -20.4081   57.7000     77.29        65          75
# 6      Songjianghe  42.1859  127.4790     48.81        97         100
# 7             Hilo  19.7297 -155.0900     79.29        90           0
# 8           Valera   9.3178  -70.6036     69.35        77          68
# 9        Hithadhoo  -0.6000   73.0833     82.13        68          94
#
#    Wind Speed Country   Current Description
# 0        5.75      CA             clear sky
# 1       11.83      VN         broken clouds
# 2       19.57      ZA             clear sky
# 3       19.10      PF             clear sky
# 4       17.27      MU         broken clouds
# 5       17.27      MU         broken clouds
# 6       10.13      CN  heavy intensity rain
# 7        4.61      US             clear sky
# 8        5.17      VE         broken clouds
# 9       15.17      MV       overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Thompson      CA  55.7435  -97.8558     51.96        82           0
# 1       Phan Thiet      VN  10.9333  108.1000     83.68        76          82
# 2      East London      ZA -33.0153   27.9116     67.14        72           0
# 3           Atuona      PF  -9.8000 -139.0333     76.69        74           9
# 4  Bambous Virieux      MU -20.3428   57.7575     77.25        65          75
# 5        Mahebourg      MU -20.4081   57.7000     77.29        65          75
# 6      Songjianghe      CN  42.1859  127.4790     48.81        97         100
# 7             Hilo      US  19.7297 -155.0900     79.29        90           0
# 8           Valera      VE   9.3178  -70.6036     69.35        77          68
# 9        Hithadhoo      MV  -0.6000   73.0833     82.13        68          94
#
#    Wind Speed   Current Description
# 0        5.75             clear sky
# 1       11.83         broken clouds
# 2       19.57             clear sky
# 3       19.10             clear sky
# 4       17.27         broken clouds
# 5       17.27         broken clouds
# 6       10.13  heavy intensity rain
# 7        4.61             clear sky
# 8        5.17         broken clouds
# 9       15.17       overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data DataFrame into a CSV file.
city_data_df.to_csv(output_data_file)
